# %%
import pandas as pd

df = pd.read_csv (r'C:\Users\massi\Desktop\PRINCIPI\base.csv')
print (df)

# %%
import pandas as pd

df = pd.read_csv (r'C:\Users\massi\Desktop\PRINCIPI\base.csv')
print (df)
# Out:
#       MQ2  MQ3  MQ5  MQ135
# 0     137  177  201     33
# 1     136  177  201     34
# 2     137  177  201     34
# 3     136  177  201     34
# 4     136  177  201     34
# ...   ...  ...  ...    ...
# 1449  136  139  203     34
# 1450  136  139  203     34
# 1451  136  139  203     34
# 1452  136  139  203     34
# 1453  137  139  203     33
#
# [1454 rows x 4 columns]

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv (r'C:\Users\massi\Desktop\PRINCIPI\base.csv')
print (df)
 
# x axis values
x = [1,2,3]
# corresponding y axis values
y = [2,4,1]
 
# plotting the points
plt.plot(df)
 
# naming the x axis
##plt.xlabel('x - axis')
# naming the y axis
##plt.ylabel('y - axis')
 
# giving a title to my graph
#plt.title('My first graph!')
 
# function to show the plot
#plt.show()
# Out:
#      1376  177  202      3
# 0     MQ2  MQ3  MQ5  MQ135
# 1     137  177  201     33
# 2     136  177  201     34
# 3     137  177  201     34
# 4     136  177  201     34
# ...   ...  ...  ...    ...
# 5486  137  124  207     34
# 5487  137  124  207     34
# 5488  137  124  208     34
# 5489  136  124  207     34
# 5490  136  124  207     34
#
# [5491 rows x 4 columns]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20828/1848129028.py in <module>
#      11
#      12 # plotting the points
# ---> 13 plt.plot(df)
#      14
#      15 # naming the x axis
#
# ~\miniconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2755 @_copy_docstring_and_deprecators(Axes.plot)
#    2756 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2757     return gca().plot(
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv (r'C:\Users\massi\Desktop\PRINCIPI\base.csv')
print (df)
# Out:
#      1376  177  202      3
# 0     MQ2  MQ3  MQ5  MQ135
# 1     137  177  201     33
# 2     136  177  201     34
# 3     137  177  201     34
# 4     136  177  201     34
# ...   ...  ...  ...    ...
# 5486  137  124  207     34
# 5487  137  124  207     34
# 5488  137  124  208     34
# 5489  136  124  207     34
# 5490  136  124  207     34
#
# [5491 rows x 4 columns]

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv (r'C:\Users\massi\Desktop\PRINCIPI\base.csv')
plt.plot(df)
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv (r'C:\Users\massi\Desktop\PRINCIPI\deodorante.csv')
plt.plot(df)
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv (r'C:\Users\massi\Desktop\PRINCIPI\base.csv')
#print(df)
plt.plot(df["MQ2"], label = "MQ2")
plt.plot(df["MQ3"], label = "MQ3")
plt.plot(df["MQ5"], label = "MQ5")
plt.plot(df["MQ135"], label = "MQ135")
#plt.ylabel("MQ2","MQ3","MQ5","MQ135")
plt.title('ambiente di base')

plt.legend()
plt.show()


df = pd.read_csv (r'C:\Users\massi\Desktop\PRINCIPI\banana.csv')
#print(df)
plt.plot(df["MQ2"], label = "MQ2")
plt.plot(df["MQ3"], label = "MQ3")
plt.plot(df["MQ5"], label = "MQ5")
plt.plot(df["MQ135"], label = "MQ135")
#plt.ylabel("MQ2","MQ3","MQ5","MQ135")
plt.title('Banana')

plt.legend()
plt.show()


df = pd.read_csv (r'C:\Users\massi\Desktop\PRINCIPI\caffe.csv')
#print(df)
plt.plot(df["MQ2"], label = "MQ2")
plt.plot(df["MQ3"], label = "MQ3")
plt.plot(df["MQ5"], label = "MQ5")
plt.plot(df["MQ135"], label = "MQ135")
#plt.ylabel("MQ2","MQ3","MQ5","MQ135")
plt.title('caffe')

plt.legend()
plt.show()

df = pd.read_csv (r'C:\Users\massi\Desktop\PRINCIPI\deodorante.csv')
#print(df)
plt.plot(df["MQ2"], label = "MQ2")
plt.plot(df["MQ3"], label = "MQ3")
plt.plot(df["MQ5"], label = "MQ5")
plt.plot(df["MQ135"], label = "MQ135")
#plt.ylabel("MQ2","MQ3","MQ5","MQ135")
plt.title('deodorante')

plt.legend()
plt.show()

df = pd.read_csv (r'C:\Users\massi\Desktop\PRINCIPI\sudore.csv')
#print(df)
plt.plot(df["MQ2"], label = "MQ2")
plt.plot(df["MQ3"], label = "MQ3")
plt.plot(df["MQ5"], label = "MQ5")
plt.plot(df["MQ135"], label = "MQ135")
#plt.ylabel("MQ2","MQ3","MQ5","MQ135")
plt.title('sudore')

plt.legend()
plt.show()

df = pd.read_csv (r'C:\Users\massi\Desktop\PRINCIPI\sigaretta.csv')
#print(df)
plt.plot(df["MQ2"], label = "MQ2")
plt.plot(df["MQ3"], label = "MQ3")
plt.plot(df["MQ5"], label = "MQ5")
plt.plot(df["MQ135"], label = "MQ135")
#plt.ylabel("MQ2","MQ3","MQ5","MQ135")
plt.title('sigaretta')

plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv (r'C:\Users\massi\Desktop\PRINCIPI\gin.csv')
#print(df)
plt.plot(df["MQ2"], label = "MQ2")
plt.plot(df["MQ3"], label = "MQ3")
plt.plot(df["MQ5"], label = "MQ5")
plt.plot(df["MQ135"], label = "MQ135")
#plt.ylabel("MQ2","MQ3","MQ5","MQ135")
plt.title('gin')

plt.legend()
plt.show()


df = pd.read_csv (r'C:\Users\massi\Desktop\PRINCIPI\zippo.csv')
#print(df)
plt.plot(df["MQ2"], label = "MQ2")
plt.plot(df["MQ3"], label = "MQ3")
plt.plot(df["MQ5"], label = "MQ5")
plt.plot(df["MQ135"], label = "MQ135")
#plt.ylabel("MQ2","MQ3","MQ5","MQ135")
plt.title('zippo')

plt.legend()
plt.show()

df = pd.read_csv (r'C:\Users\massi\Desktop\PRINCIPI\gas.csv')
#print(df)
plt.plot(df["MQ2"], label = "MQ2")
plt.plot(df["MQ3"], label = "MQ3")
plt.plot(df["MQ5"], label = "MQ5")
plt.plot(df["MQ135"], label = "MQ135")
#plt.ylabel("MQ2","MQ3","MQ5","MQ135")
plt.title('gas')

plt.legend()
plt.show()

df = pd.read_csv (r'C:\Users\massi\Desktop\PRINCIPI\fornelli.csv')
#print(df)
plt.plot(df["MQ2"], label = "MQ2")
plt.plot(df["MQ3"], label = "MQ3")
plt.plot(df["MQ5"], label = "MQ5")
plt.plot(df["MQ135"], label = "MQ135")
#plt.ylabel("MQ2","MQ3","MQ5","MQ135")
plt.title('fornelli')

plt.legend()
plt.show()

df = pd.read_csv (r'C:\Users\massi\Desktop\PRINCIPI\muffa.csv')
#print(df)
plt.plot(df["MQ2"], label = "MQ2")
plt.plot(df["MQ3"], label = "MQ3")
plt.plot(df["MQ5"], label = "MQ5")
plt.plot(df["MQ135"], label = "MQ135")
#plt.ylabel("MQ2","MQ3","MQ5","MQ135")
plt.title('Muffa')

plt.legend()
plt.show()
